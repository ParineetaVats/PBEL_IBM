# %%
a=12
print(a)
print(type(a))
# Out:
# 12
# <class 'int'>

# %%
user=input("Enter your name: ")
print("hello", user)
print(type(user))
# Out:
# hello
# <class 'str'>

# %%
user_num=(input("Enter your number: "))
print("hello", user_num)
print(type(user_num))
